# %%
# Using Pandas - the geopandas i tried to use did not work so i used folium  see Geopandas_section-2.ipynb

# # using a combination of 
# https://www.datacamp.com/tutorial/geopandas-tutorial-geospatial-analysis

# https://geopandas.org/en/stable/getting_started/introduction.html
# and asking Chat GPT to explain the concepts of why and how to use pandas with a CRS.

# https://www.linkedin.com/pulse/mapping-australian-geograph-data-python-dilan-jayasekara/

# %%
# !pip install geopandas

# %%
conda install geopandas
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 24.3.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.3.0
#
#
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# conda install conda=24.3.0

# %%
import geopandas
# from geodatasets import get_path

import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

# from geodatasets import get_path
import shapely as shp
from shapely.geometry import Polygon, LineString

from shapely.geometry import Point

# %%
#help(shp.geometry)
#help(shp.geometry).polygon

# %%
frog_data_file_location = pd.read_csv('./cleaned_frog_data.csv')

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
                                            
world.plot()
plt.show()
# Out:
# /var/folders/4y/ymqhs2g96_s47swtxxllz3600000gn/T/ipykernel_69084/1710772082.py:1: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
# help(plt.plot)

# %%
# not working so used Folium below
frog_data_file_location = pd.read_csv('./last_10years_clean_df.csv')

geo_df = gpd.GeoDataFrame(frog_data_file_location, geometry= gpd.points_from_xy(frog_data_file_location['Longitude'],frog_data_file_location['Latitude']))

world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
fig = world.plot(color= 'lightgrey', figsize = (10,6))

geo_df.plot(ax=fig, markersize = geo_fd['Population'], color='green', alpha = 0.5)
plt.show()
# Out:
# /var/folders/4y/ymqhs2g96_s47swtxxllz3600000gn/T/ipykernel_69084/1989993035.py:6: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 9
#       6 world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
#       7 fig = world.plot(color= 'lightgrey', figsize = (10,6))
# ----> 9 geo_df.plot(ax=fig, markersize = geo_fd['Population'], color='green', alpha = 0.5)
#      10 plt.show()
#
# NameError: name 'geo_fd' is not defined
